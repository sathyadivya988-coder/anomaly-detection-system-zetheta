# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\it272\\Documents\\anomaly-detection-system\\notebooks'

# %%
import shutil
import os

# Source path (where CSV is currently)
source = r"C:\Users\it272\OneDrive\Documents\anamoly-detection-system\data\raw\creditcard.csv"

# Destination folder (your real project)
destination_folder = r"C:\Users\it272\Documents\anomaly-detection-system\data\raw"

# Create destination folder if not exists
os.makedirs(destination_folder, exist_ok=True)

# Copy file
shutil.copy(source, destination_folder)

print("✅ File copied successfully!")
# Out:
# --------------------------------------------------------------
# FileNotFoundError            Traceback (most recent call last)
# Cell In[2], line 14
#      11 os.makedirs(destination_folder, exist_ok=True)
#      13 # Copy file
# ---> 14 shutil.copy(source, destination_folder)
#      16 print("✅ File copied successfully!")
#
# File C:\Python314\Lib\shutil.py:489, in copy(src, dst, follow_symlinks)
#     487 if os.path.isdir(dst):
#     488     dst = os.path.join(dst, os.path.basename(src))
# --> 489 copyfile(src, dst, follow_symlinks=follow_symlinks)
#     490 copymode(src, dst, follow_symlinks=follow_symlinks)
#     491 return dst
#
# File C:\Python314\Lib\shutil.py:313, in copyfile(src, dst, follow_symlinks)
#     311     os.symlink(os.readlink(src), dst)
#     312 else:
# --> 313     with open(src, 'rb') as fsrc:
#     314         try:
#     315             with open(dst, 'wb') as fdst:
#     316                 # macOS
#
# ...

# %%
import os

for root, dirs, files in os.walk(r"C:\Users\it272"):
    for file in files:
        if file == "creditcard.csv":
            print(os.path.join(root, file))
# Out:
# C:\Users\it272\OneDrive\Documents\anomaly-detection-system\data\raw\creditcard.csv

# %%
import shutil
import os

# Source path
source = r"C:\Users\it272\OneDrive\Documents\anomaly-detection-system\data\raw\creditcard.csv"

# Destination folder (inside your real project)
destination_folder = r"C:\Users\it272\Documents\anomaly-detection-system\data\raw"

# Create destination folder if not exists
os.makedirs(destination_folder, exist_ok=True)

# Copy CSV
shutil.copy(source, destination_folder)

print("✅ creditcard.csv copied successfully!")
# Out:
# ✅ creditcard.csv copied successfully!

# %%
os.listdir(r"C:\Users\it272\Documents\anomaly-detection-system\data\raw")
# Out:
# ['.gitkeep', 'creditcard.csv']
